# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import sklearn
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    cohen_kappa_score,
    confusion_matrix,
)
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier

# %%
df = pd.read_csv("BDOShoham.csv").dropna()
df
# Out:
#       FlowPattern      Vsl      Vsg   VisL     VisG  DenL  DenG    ST   Ang  \
# 0               1  6.30000   0.0250  0.001  0.00002  1000   1.8  0.07   0.0
# 1               1  4.00000   0.0400  0.001  0.00002  1000   1.8  0.07   0.0
# 2               1  6.30000   0.0400  0.001  0.00002  1000   1.8  0.07   0.0
# 3               1  4.00000   0.0630  0.001  0.00002  1000   1.8  0.07   0.0
# 4               1  6.30000   0.0630  0.001  0.00002  1000   1.8  0.07   0.0
# ...           ...      ...      ...    ...      ...   ...   ...   ...   ...
# 5670            5  2.70096  15.8561  0.001  0.00002  1000   1.8  0.07 -80.0
# 5671            5  1.58784  15.8394  0.001  0.00002  1000   1.8  0.07 -80.0
# 5672            5  1.05338  16.0692  0.001  0.00002  1000   1.8  0.07 -80.0
# 5673            5  1.05397  25.7439  0.001  0.00002  1000   1.8  0.07 -80.0
# 5674            5  1.66789  26.1616  0.001  0.00002  1000   1.8  0.07 -80.0
#
#          ID
# 0     0.051
# 1     0.051
# 2     0.051
# 3     0.051
# 4     0.051
# ...     ...
# 5670  0.025
# 5671  0.025
# 5672  0.025
# 5673  0.025
# 5674  0.025
#
# [5675 rows x 10 columns]

# %%
df.describe()
# Out:
#        FlowPattern          Vsl          Vsg          VisL          VisG  \
# count  5675.000000  5675.000000  5675.000000  5.675000e+03  5.675000e+03
# mean      4.059912     0.899747     6.222612  1.000000e-03  2.000000e-05
# std       1.379238     1.425159     8.699644  2.168595e-19  3.388430e-21
# min       1.000000     0.001100     0.003720  1.000000e-03  2.000000e-05
# 25%       3.000000     0.016000     0.162055  1.000000e-03  2.000000e-05
# 50%       5.000000     0.250000     1.600000  1.000000e-03  2.000000e-05
# 75%       5.000000     1.500000    10.000000  1.000000e-03  2.000000e-05
# max       7.000000    25.517000    42.956200  1.000000e-03  2.000000e-05
#
#          DenL          DenG            ST          Ang           ID
# count  5675.0  5.675000e+03  5.675000e+03  5675.000000  5675.000000
# mean   1000.0  1.800000e+00  7.000000e-02     2.727401     0.038657
# std       0.0  6.661925e-16  1.387901e-17    46.202822     0.012985
# min    1000.0  1.800000e+00  7.000000e-02   -90.000000     0.025000
# 25%    1000.0  1.800000e+00  7.000000e-02   -10.000000     0.025000
# 50%    1000.0  1.800000e+00  7.000000e-02     0.500000     0.051000
# 75%    1000.0  1.800000e+00  7.000000e-02    20.000000     0.051000
# max    1000.0  1.800000e+00  7.000000e-02    90.000000     0.051000

# %%
df.hist(figsize=(15, 10), bins=50)

plt.show()

# %%
X_names = ["Vsl", "Vsg", "Ang"]
y_name = "FlowPattern"

X = df[X_names]
y = df[y_name]

# %%
corr = X.corr()

sns.heatmap(corr, cmap="bwr", vmin=-1, vmax=1, annot=True)

plt.show()

pd.plotting.scatter_matrix(X, figsize=(12, 12))

plt.show()

# %%
test_pct = 0.20
seed = 7

X_train, X_test, y_train, y_test = model_selection.train_test_split(
    X, y, test_size=test_pct, random_state=seed
)

# %%
models = [
    ("LR", LogisticRegression(multi_class="multinomial", max_iter=1000)),
    ("Ridge", RidgeClassifier(alpha=10)),
    (
        "KNN",
        KNeighborsClassifier(n_neighbors=5, weights="uniform"),
    ),
]

# %%
# sklearn.metrics.get_scorer_names()

# %%
from itertools import product

scoring = ["accuracy", "recall_macro", "f1_macro", "precision_macro", "recall_micro", "f1_micro", "precision_micro"]
k4folds = 5
results = []
names = []

for scoring_method, (name, model) in product(scoring, models):
    print(f" ++ NOW WORKING ON ALGORITHM {name} ++")
    print(f"Splitting data into {k4folds} folds")
    kfold = model_selection.KFold(n_splits=k4folds, random_state=seed, shuffle=True)
    print("Training model on each split")
    cv_results = model_selection.cross_val_score(
        model,
        X_train,
        y_train,
        cv=kfold,
        scoring=scoring_method,
        n_jobs=5,
    )

    msg = f"algorithm {name} {scoring_method} results: mean = {cv_results.mean():.3f} (std = {cv_results.std():.3f})"
    print(msg, end="\n\n")

    results.append((name, scoring_method, cv_results))
print("done.")
# Out:
#  ++ NOW WORKING ON ALGORITHM LR ++
# Splitting data into 5 folds
# Training model on each split
# algorithm LR accuracy results: mean = 0.668 (std = 0.010)
#
#  ++ NOW WORKING ON ALGORITHM Ridge ++
# Splitting data into 5 folds
# Training model on each split
# algorithm Ridge accuracy results: mean = 0.609 (std = 0.010)
#
#  ++ NOW WORKING ON ALGORITHM KNN ++
# Splitting data into 5 folds
# Training model on each split
# algorithm KNN accuracy results: mean = 0.833 (std = 0.013)
#
#  ++ NOW WORKING ON ALGORITHM LR ++
# Splitting data into 5 folds
# Training model on each split
# algorithm LR recall_macro results: mean = 0.481 (std = 0.020)
#
#  ++ NOW WORKING ON ALGORITHM Ridge ++
# Splitting data into 5 folds
# Training model on each split
# algorithm Ridge recall_macro results: mean = 0.295 (std = 0.006)
#
#  ++ NOW WORKING ON ALGORITHM KNN ++
# Splitting data into 5 folds
# Training model on each split
# algorithm KNN recall_macro results: mean = 0.816 (std = 0.020)
#
#  ++ NOW WORKING ON ALGORITHM LR ++
# Splitting data into 5 folds
# Training model on each split
# algorithm LR f1_macro results: mean = 0.493 (std = 0.012)
#
#  ++ NOW WORKING ON ALGORITHM Ridge ++
# Splitting data into 5 folds
# Training model on each split
# algorithm Ridge f1_macro results: mean = 0.282 (std = 0.008)
#
#  ++ NOW WORKING ON ALGORITHM KNN ++
# Splitting data into 5 folds
# Training model on each split
# algorithm KNN f1_macro results: mean = 0.796 (std = 0.017)
#
#  ++ NOW WORKING ON ALGORITHM LR ++
# Splitting data into 5 folds
# Training model on each split
# /home/apwood/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/apwood/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/apwood/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/apwood/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/apwood/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/apwood/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/apwood/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/apwood/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/apwood/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/apwood/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# algorithm LR precision_macro results: mean = 0.531 (std = 0.007)
#
#  ++ NOW WORKING ON ALGORITHM Ridge ++
# Splitting data into 5 folds
# Training model on each split
# algorithm Ridge precision_macro results: mean = 0.342 (std = 0.025)
#
#  ++ NOW WORKING ON ALGORITHM KNN ++
# Splitting data into 5 folds
# Training model on each split
# algorithm KNN precision_macro results: mean = 0.782 (std = 0.018)
#
#  ++ NOW WORKING ON ALGORITHM LR ++
# Splitting data into 5 folds
# Training model on each split
# algorithm LR recall_micro results: mean = 0.668 (std = 0.010)
#
#  ++ NOW WORKING ON ALGORITHM Ridge ++
# Splitting data into 5 folds
# Training model on each split
# algorithm Ridge recall_micro results: mean = 0.609 (std = 0.010)
#
#  ++ NOW WORKING ON ALGORITHM KNN ++
# Splitting data into 5 folds
# Training model on each split
# algorithm KNN recall_micro results: mean = 0.833 (std = 0.013)
#
#  ++ NOW WORKING ON ALGORITHM LR ++
# Splitting data into 5 folds
# Training model on each split
# algorithm LR f1_micro results: mean = 0.668 (std = 0.010)
#
#  ++ NOW WORKING ON ALGORITHM Ridge ++
# Splitting data into 5 folds
# Training model on each split
# algorithm Ridge f1_micro results: mean = 0.609 (std = 0.010)
#
#  ++ NOW WORKING ON ALGORITHM KNN ++
# Splitting data into 5 folds
# Training model on each split
# algorithm KNN f1_micro results: mean = 0.833 (std = 0.013)
#
#  ++ NOW WORKING ON ALGORITHM LR ++
# Splitting data into 5 folds
# Training model on each split
# algorithm LR precision_micro results: mean = 0.668 (std = 0.010)
#
#  ++ NOW WORKING ON ALGORITHM Ridge ++
# Splitting data into 5 folds
# Training model on each split
# algorithm Ridge precision_micro results: mean = 0.609 (std = 0.010)
#
#  ++ NOW WORKING ON ALGORITHM KNN ++
# Splitting data into 5 folds
# Training model on each split
# algorithm KNN precision_micro results: mean = 0.833 (std = 0.013)
#
# done.

# %%
for name, scoring_method, res in results:
    fig = plt.figure()
    fig.suptitle(f"Algorithm Comparison based on {name}, {scoring_method=}")
    ax = fig.add_subplot(111)
    plt.boxplot(res)
    ax.set_xticklabels(names)
    plt.show()

# %%
selected_model = KNeighborsClassifier()

parameters = {
    "n_neighbors": range(1, 20, 2),
    "weights": ("uniform", "distance"),
    "p": (1, 2),
}

clf = GridSearchCV(selected_model, parameters, cv=5, scoring="accuracy")
clf.fit(X_train, y_train)

print("Best parameters set found on development set:")
print(clf.best_params_)
print("Grid scores on development set:")

means = clf.cv_results_["mean_test_score"]
stds = clf.cv_results_["std_test_score"]

for mean, std, params in zip(means, stds, clf.cv_results_["params"]):
    print(f"{mean:0.03f} (+/-{std:0.03}) for {params}")


y_true, y_pred = y_test, clf.predict(X_test)

print("Detailed classification report:")
print(classification_report(y_true, y_pred))

df_cm = pd.DataFrame(
    confusion_matrix(y_test, y_pred, normalize='true'), columns=np.unique(y_test), index=np.unique(y_test)
)

sns.heatmap(
    df_cm,
    square=True,
    annot=True,
    # fmt="d",
    cbar=False,
)
plt.xlabel("predicted")
plt.ylabel("true")
plt.show()

print("Cohen Kappa Score:", cohen_kappa_score(y_test, y_pred))

print("done.")
# Out:
# Best parameters set found on development set:
# {'n_neighbors': 1, 'p': 2, 'weights': 'uniform'}
# Grid scores on development set:
# 0.869 (+/-0.0118) for {'n_neighbors': 1, 'p': 1, 'weights': 'uniform'}
# 0.869 (+/-0.0118) for {'n_neighbors': 1, 'p': 1, 'weights': 'distance'}
# 0.870 (+/-0.0101) for {'n_neighbors': 1, 'p': 2, 'weights': 'uniform'}
# 0.870 (+/-0.0101) for {'n_neighbors': 1, 'p': 2, 'weights': 'distance'}
# 0.856 (+/-0.00702) for {'n_neighbors': 3, 'p': 1, 'weights': 'uniform'}
# 0.862 (+/-0.00821) for {'n_neighbors': 3, 'p': 1, 'weights': 'distance'}
# 0.855 (+/-0.00615) for {'n_neighbors': 3, 'p': 2, 'weights': 'uniform'}
# 0.863 (+/-0.00761) for {'n_neighbors': 3, 'p': 2, 'weights': 'distance'}
# 0.842 (+/-0.00677) for {'n_neighbors': 5, 'p': 1, 'weights': 'uniform'}
# 0.860 (+/-0.00677) for {'n_neighbors': 5, 'p': 1, 'weights': 'distance'}
# 0.843 (+/-0.00932) for {'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}
# 0.858 (+/-0.00719) for {'n_neighbors': 5, 'p': 2, 'weights': 'distance'}
# 0.827 (+/-0.0106) for {'n_neighbors': 7, 'p': 1, 'weights': 'uniform'}
# 0.855 (+/-0.00843) for {'n_neighbors': 7, 'p': 1, 'weights': 'distance'}
# 0.828 (+/-0.0127) for {'n_neighbors': 7, 'p': 2, 'weights': 'uniform'}
# 0.855 (+/-0.0101) for {'n_neighbors': 7, 'p': 2, 'weights': 'distance'}
# 0.814 (+/-0.013) for {'n_neighbors': 9, 'p': 1, 'weights': 'uniform'}
# 0.847 (+/-0.0106) for {'n_neighbors': 9, 'p': 1, 'weights': 'distance'}
# 0.814 (+/-0.0169) for {'n_neighbors': 9, 'p': 2, 'weights': 'uniform'}
# 0.847 (+/-0.00939) for {'n_neighbors': 9, 'p': 2, 'weights': 'distance'}
# 0.810 (+/-0.0123) for {'n_neighbors': 11, 'p': 1, 'weights': 'uniform'}
# 0.844 (+/-0.00879) for {'n_neighbors': 11, 'p': 1, 'weights': 'distance'}
# 0.807 (+/-0.0161) for {'n_neighbors': 11, 'p': 2, 'weights': 'uniform'}
# 0.845 (+/-0.0103) for {'n_neighbors': 11, 'p': 2, 'weights': 'distance'}
# 0.803 (+/-0.0125) for {'n_neighbors': 13, 'p': 1, 'weights': 'uniform'}
# 0.844 (+/-0.00851) for {'n_neighbors': 13, 'p': 1, 'weights': 'distance'}
# 0.799 (+/-0.0137) for {'n_neighbors': 13, 'p': 2, 'weights': 'uniform'}
# 0.844 (+/-0.00916) for {'n_neighbors': 13, 'p': 2, 'weights': 'distance'}
# 0.799 (+/-0.0152) for {'n_neighbors': 15, 'p': 1, 'weights': 'uniform'}
# 0.845 (+/-0.00786) for {'n_neighbors': 15, 'p': 1, 'weights': 'distance'}
# 0.799 (+/-0.0139) for {'n_neighbors': 15, 'p': 2, 'weights': 'uniform'}
# 0.842 (+/-0.00883) for {'n_neighbors': 15, 'p': 2, 'weights': 'distance'}
# 0.794 (+/-0.0141) for {'n_neighbors': 17, 'p': 1, 'weights': 'uniform'}
# 0.845 (+/-0.00732) for {'n_neighbors': 17, 'p': 1, 'weights': 'distance'}
# 0.796 (+/-0.0126) for {'n_neighbors': 17, 'p': 2, 'weights': 'uniform'}
# 0.841 (+/-0.00792) for {'n_neighbors': 17, 'p': 2, 'weights': 'distance'}
# 0.795 (+/-0.00951) for {'n_neighbors': 19, 'p': 1, 'weights': 'uniform'}
# 0.845 (+/-0.00719) for {'n_neighbors': 19, 'p': 1, 'weights': 'distance'}
# 0.794 (+/-0.0114) for {'n_neighbors': 19, 'p': 2, 'weights': 'uniform'}
# 0.841 (+/-0.00832) for {'n_neighbors': 19, 'p': 2, 'weights': 'distance'}
# Detailed classification report:
#               precision    recall  f1-score   support
#
#            1       0.73      0.81      0.77       116
#            2       0.79      0.85      0.82        27
#            3       0.83      0.86      0.85       184
#            4       0.85      0.84      0.85       217
#            5       0.92      0.87      0.89       570
#            7       0.52      0.71      0.60        21
#
#     accuracy                           0.85      1135
#    macro avg       0.77      0.83      0.80      1135
# weighted avg       0.86      0.85      0.86      1135
# Cohen Kappa Score: 0.7875455340602144
# done.

# %% [markdown]
# ## Discussion
#
# During the initial cross validation step, the kNN classifier consistently performed better than the LogisticRegression or Ridge classifiers regardless of scoring metric used.
#
# The kNN performed the task of predicting the FlowPattern class most reliably with the following hyperparameter configuration:
# ```
# n_neighbors = 1
# weights = 'uniform'
# p = 2
# ```
#
# The final accuracy of the trained kNN classifier is 0.85, with a Cohen's Kappa of ~0.79.
# Since not all FlowPatterns were represented in the dataset with equal statistics, I normalized the final confusion matrix to the number of True FlowPatterns.
# The least performant classification occurred when attempting to predict FlowPattern 7, where 19% of the samples were misclassified as FlowPattern 5, and another 9.5% as FlowPattern 1.
